# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in c:\users\shemw\anaconda3\lib\site-packages (0.12.1.post1)
# Requirement already satisfied: numpy in c:\users\shemw\anaconda3\lib\site-packages (from folium) (1.21.5)
# Requirement already satisfied: requests in c:\users\shemw\anaconda3\lib\site-packages (from folium) (2.27.1)
# Requirement already satisfied: branca>=0.3.0 in c:\users\shemw\anaconda3\lib\site-packages (from folium) (0.5.0)
# Requirement already satisfied: jinja2>=2.9 in c:\users\shemw\anaconda3\lib\site-packages (from folium) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\shemw\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shemw\anaconda3\lib\site-packages (from requests->folium) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shemw\anaconda3\lib\site-packages (from requests->folium) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\shemw\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\shemw\anaconda3\lib\site-packages (from requests->folium) (1.26.9)

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import os
import folium

# %%
df = pd.read_csv("C:\\Users\\shemw\\Downloads\\Crimes_-_2001_to_Present.csv")
print(df)
# Out:
# C:\Users\shemw\AppData\Local\Temp\ipykernel_25608\2174314682.py:1: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("C:\\Users\\shemw\\Downloads\\Crimes_-_2001_to_Present.csv")
#               ID Case Number              Date                    Block  IUCR  \
# 0       12014684    JD189901   3/17/2020 21:30     039XX N LECLAIRE AVE   820
# 1       11864018    JC476123    9/24/2019 8:00     022XX S MICHIGAN AVE  1154
# 2       11859805    JC471592  10/13/2019 20:30      024XX W CHICAGO AVE   860
# 3       12571973    JE482457   12/19/2021 7:23        042XX S MOZART ST   460
# 4       12012127    JD189186    3/18/2020 2:03     039XX W JACKSON BLVD   910
# ...          ...         ...               ...                      ...   ...
# 842335  12814830    JF381315    8/14/2022 0:00         040XX N BROADWAY  1206
# 842336  12815209    JF381666    9/3/2022 13:18  013XX S SPRINGFIELD AVE   420
# 842337  12815281    JF381762    9/3/2022 14:45   116XX S MARSHFIELD AVE   918
# 842338  12819666    JF386901     9/1/2022 0:00      079XX S CRANDON AVE  031A
# 842339  12815081    JF380892    9/2/2022 21:49      062XX S NEWLAND AVE   486
#
#                Primary Type                              Description  \
# 0                     THEFT                           $500 AND UNDER
# 1        DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 2                     THEFT                             RETAIL THEFT
# 3                   BATTERY                                   SIMPLE
# 4       MOTOR VEHICLE THEFT                               AUTOMOBILE
# ...                     ...                                      ...
# 842335   DECEPTIVE PRACTICE           THEFT BY LESSEE, MOTOR VEHICLE
# 842336              BATTERY  AGGRAVATED - KNIFE / CUTTING INSTRUMENT
# 842337  MOTOR VEHICLE THEFT              CYCLE, SCOOTER, BIKE NO VIN
# 842338              ROBBERY                          ARMED - HANDGUN
# 842339              BATTERY                  DOMESTIC BATTERY SIMPLE
#
#                           Location Description  Arrest  Domestic  ...  Ward  \
# 0                                       STREET   False     False  ...  45.0
# 1                 COMMERCIAL / BUSINESS OFFICE   False     False  ...   3.0
# 2                           GROCERY FOOD STORE   False     False  ...  26.0
# 3                                     SIDEWALK    True      True  ...  15.0
# 4                                    APARTMENT   False      True  ...  28.0
# ...                                        ...     ...       ...  ...   ...
# 842335            COMMERCIAL / BUSINESS OFFICE   False     False  ...  46.0
# 842336                                  STREET    True     False  ...  24.0
# 842337  PARKING LOT / GARAGE (NON RESIDENTIAL)   False     False  ...  34.0
# 842338                                   ALLEY   False     False  ...   7.0
# 842339                               APARTMENT   False      True  ...  23.0
#
#         Community Area  FBI Code  X Coordinate Y Coordinate  Year  \
# 0                 15.0         6     1141659.0    1925649.0  2020
# 1                 33.0        11     1177560.0    1889548.0  2019
# 2                 24.0         6     1160005.0    1905256.0  2019
# 3                 58.0       08B     1158067.0    1876425.0  2021
# 4                 26.0         7     1150196.0    1898398.0  2020
# ...                ...       ...           ...          ...   ...
# 842335             3.0        11           NaN          NaN  2022
# 842336            29.0       04B           NaN          NaN  2022
# 842337            75.0         7           NaN          NaN  2022
# 842338            46.0         3           NaN          NaN  2022
# 842339            64.0       08B           NaN          NaN  2022
#
#               Updated On   Latitude  Longitude                       Location
# 0        3/25/2020 15:45  41.952052 -87.754660  (41.952051946, -87.754660372)
# 1       10/20/2019 15:56  41.852248 -87.623786  (41.852248185, -87.623786256)
# 2       10/20/2019 16:03  41.895732 -87.687784  (41.895732399, -87.687784384)
# 3        9/12/2022 16:45  41.816657 -87.695689   (41.81665685, -87.695688608)
# 4        3/25/2020 15:47  41.877110 -87.723990  (41.877110187, -87.723989719)
# ...                  ...        ...        ...                            ...
# 842335   9/23/2022 16:45        NaN        NaN                            NaN
# 842336   9/23/2022 16:45        NaN        NaN                            NaN
# 842337   9/23/2022 16:45        NaN        NaN                            NaN
# 842338   9/23/2022 16:45        NaN        NaN                            NaN
# 842339   9/23/2022 16:45        NaN        NaN                            NaN
#
# [842340 rows x 22 columns]

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 842340 entries, 0 to 842339
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    842340 non-null  int64
#  1   Case Number           842340 non-null  object
#  2   Date                  842340 non-null  object
#  3   Block                 842340 non-null  object
#  4   IUCR                  842340 non-null  object
#  5   Primary Type          842340 non-null  object
#  6   Description           842340 non-null  object
#  7   Location Description  838550 non-null  object
#  8   Arrest                842340 non-null  bool
#  9   Domestic              842340 non-null  bool
#  10  Beat                  842340 non-null  int64
#  11  District              842340 non-null  int64
#  12  Ward                  842296 non-null  float64
#  13  Community Area        842339 non-null  float64
#  14  FBI Code              842340 non-null  object
#  15  X Coordinate          671037 non-null  float64
#  16  Y Coordinate          671037 non-null  float64
#  17  Year                  842340 non-null  int64
#  18  Updated On            842340 non-null  object
#  19  Latitude              671037 non-null  float64
#  20  Longitude             671037 non-null  float64
#  21  Location              671037 non-null  object
# dtypes: bool(2), float64(6), int64(4), object(10)
# memory usage: 619.0 MB

# %%
#Resetting the index 
index_names = df[df['Latitude']=='(41.789832136, -87.672973835)'].index
df.drop(index_names, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 842340 entries, 0 to 842339
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    842340 non-null  int64
#  1   Case Number           842340 non-null  object
#  2   Date                  842340 non-null  object
#  3   Block                 842340 non-null  object
#  4   IUCR                  842340 non-null  object
#  5   Primary Type          842340 non-null  object
#  6   Description           842340 non-null  object
#  7   Location Description  838550 non-null  object
#  8   Arrest                842340 non-null  bool
#  9   Domestic              842340 non-null  bool
#  10  Beat                  842340 non-null  int64
#  11  District              842340 non-null  int64
#  12  Ward                  842296 non-null  float64
#  13  Community Area        842339 non-null  float64
#  14  FBI Code              842340 non-null  object
#  15  X Coordinate          671037 non-null  float64
#  16  Y Coordinate          671037 non-null  float64
#  17  Year                  842340 non-null  int64
#  18  Updated On            842340 non-null  object
#  19  Latitude              671037 non-null  float64
#  20  Longitude             671037 non-null  float64
#  21  Location              671037 non-null  object
# dtypes: bool(2), float64(6), int64(4), object(10)
# memory usage: 130.1+ MB

# %%
#Changing Latitudes data type to a float
df['Latitude'] = df['Latitude'].astype('float64')

# %%
#Plot missing values
plt.figure(figsize=(9,10), dpi=93)
plt.title('Missing Value Status',fontweight='bold')
ax = sns.heatmap(df.isna().sum().to_frame(),annot=True,fmt='d',cmap='Wistia')
ax.set_xlabel('Amount Missing')
plt.show()

# %%
#Finding null values #Yellow spaces indicate null values
plt.figure(figsize=(10,10))
sns.heatmap(df.isnull(), cbar = False, cmap = 'inferno')
# Out:
# <AxesSubplot:>

# %%
#Amount of location descriptions Per category
pd.value_counts(df['Location Description'])[:10]
# Out:
# STREET                                    202757
# APARTMENT                                 147509
# RESIDENCE                                 134869
# SIDEWALK                                   54397
# SMALL RETAIL STORE                         22772
# ALLEY                                      18144
# RESTAURANT                                 17596
# PARKING LOT / GARAGE (NON RESIDENTIAL)     17295
# VEHICLE NON-COMMERCIAL                     12836
# GAS STATION                                12363
# Name: Location Description, dtype: int64

# %%
#Type of Crimes Per Category 
pd.value_counts(df['Primary Type'])[:10]
# Out:
# THEFT                  182080
# BATTERY                160928
# CRIMINAL DAMAGE         95076
# ASSAULT                 74026
# DECEPTIVE PRACTICE      64116
# OTHER OFFENSE           53759
# MOTOR VEHICLE THEFT     40831
# NARCOTICS               30445
# BURGLARY                30242
# WEAPONS VIOLATION       30213
# Name: Primary Type, dtype: int64

# %%
crime_count = pd.DataFrame(df.groupby('Primary Type').size().sort_values(ascending=False).rename('counts').reset_index())

# %%
crime_count2 = pd.DataFrame(df.groupby('Location Description').size().sort_values(ascending=False).rename('counts').reset_index())

# %%
#Plotting Primary types and Location Description into Bar Graphs

sns.set(style="whitegrid")

f, ax = plt.subplots(figsize=(6, 15))

sns.set_color_codes("dark")
sns.barplot(x="counts", y="Primary Type", data=crime_count.iloc[:10, :],
            label="Total", color="r")

ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(ylabel="Type of crime",
       xlabel="Crimes")
sns.despine(left=True, bottom=True)

plt.show()

# %%
sns.set(style="whitegrid")

f, ax = plt.subplots(figsize=(6, 15))

sns.set_color_codes("dark")
sns.barplot(x="counts", y="Location Description", data=crime_count2.iloc[:10, :],
            label="Total", color="r")

ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(ylabel="Type of crime",
       xlabel="Crimes")
sns.despine(left=True, bottom=True)

plt.show()

# %%
import numpy as np 
import pandas as pd
import os

# %%
list = os.listdir()
  
print(list)
# Out:
# ['.anaconda', '.conda', '.condarc', '.continuum', '.eclipse', '.gitconfig', '.ipynb_checkpoints', '.ipython', '.jupyter', '.matplotlib', '.popsql.json', '.vscode', '10 min Python Challenge .ipynb', '3D Objects', 'anaconda3', 'AppData', 'Application Data', 'BullseyeCoverageError.txt', 'Challenge', 'Chi 3-Copy1.ipynb', 'Chi 3.0.ipynb', 'CHI Crimes Analysis .ipynb', 'Chicago Crime Analysis 2 .ipynb', 'Chicago Crime Analysis.ipynb', 'Chicago Crimes Folder', 'Contacts', 'Cookies', 'Crimes_-_2001_to_Present.csv', 'Documents', 'Downloads', 'edb_pgagent_pg14.exe', 'Favorites', 'File_Handling', 'iCloudDrive', 'iCloudPhotos', 'In Class Challenge', 'in Class challenge Tableu.ipynb', 'IntelGraphicsProfiles', 'Introduction to pandas.ipynb', 'Links', 'Local Settings', 'Module 1', 'module 12', 'Module 2', 'Module 5', 'Module_1', 'Music', 'Music Analysis', 'music_analysis', 'music_analysis2', 'music_analysis2.csv', 'music_analysis3', 'My Documents', 'NetHood', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{d17a4e0d-f1fd-11ec-a53f-917b1c32f7df}.TxR.0.regtrans-ms', 'NTUSER.DAT{d17a4e0d-f1fd-11ec-a53f-917b1c32f7df}.TxR.1.regtrans-ms', 'NTUSER.DAT{d17a4e0d-f1fd-11ec-a53f-917b1c32f7df}.TxR.2.regtrans-ms', 'NTUSER.DAT{d17a4e0d-f1fd-11ec-a53f-917b1c32f7df}.TxR.blf', 'NTUSER.DAT{d17a4e0e-f1fd-11ec-a53f-917b1c32f7df}.TM.blf', 'NTUSER.DAT{d17a4e0e-f1fd-11ec-a53f-917b1c32f7df}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{d17a4e0e-f1fd-11ec-a53f-917b1c32f7df}.TMContainer00000000000000000002.regtrans-ms', 'ntuser.ini', 'OneDrive', 'PrintHood', 'Recent', 'Saved Games', 'Searches', 'SendTo', 'Start Menu', 'superstore', 'Templates', 'untitled', 'Untitled Folder', 'Untitled Folder 1', 'Untitled.ipynb', 'Videos']

# %%
import os
from pathlib import Path

df2 = os.path.join(os.getcwd(), "Crimes_-_2001_to_Present.csv")

# %%
df = pd.read_csv('Crimes_-_2001_to_Present.csv')
df.head()
# Out:
# C:\Users\shemw\AppData\Local\Temp\ipykernel_25608\3909870916.py:1: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Crimes_-_2001_to_Present.csv')
#          ID Case Number              Date                 Block  IUCR  \
# 0  12014684    JD189901   3/17/2020 21:30  039XX N LECLAIRE AVE   820
# 1  11864018    JC476123    9/24/2019 8:00  022XX S MICHIGAN AVE  1154
# 2  11859805    JC471592  10/13/2019 20:30   024XX W CHICAGO AVE   860
# 3  12571973    JE482457   12/19/2021 7:23     042XX S MOZART ST   460
# 4  12012127    JD189186    3/18/2020 2:03  039XX W JACKSON BLVD   910
#
#           Primary Type                              Description  \
# 0                THEFT                           $500 AND UNDER
# 1   DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 2                THEFT                             RETAIL THEFT
# 3              BATTERY                                   SIMPLE
# 4  MOTOR VEHICLE THEFT                               AUTOMOBILE
#
#            Location Description  Arrest  Domestic  ...  Ward  Community Area  \
# 0                        STREET   False     False  ...  45.0            15.0
# 1  COMMERCIAL / BUSINESS OFFICE   False     False  ...   3.0            33.0
# 2            GROCERY FOOD STORE   False     False  ...  26.0            24.0
# 3                      SIDEWALK    True      True  ...  15.0            58.0
# 4                     APARTMENT   False      True  ...  28.0            26.0
#
#    FBI Code  X Coordinate Y Coordinate  Year        Updated On   Latitude  \
# 0         6     1141659.0    1925649.0  2020   3/25/2020 15:45  41.952052
# 1        11     1177560.0    1889548.0  2019  10/20/2019 15:56  41.852248
# 2         6     1160005.0    1905256.0  2019  10/20/2019 16:03  41.895732
# 3       08B     1158067.0    1876425.0  2021   9/12/2022 16:45  41.816657
# 4         7     1150196.0    1898398.0  2020   3/25/2020 15:47  41.877110
#
#    Longitude                       Location
# 0 -87.754660  (41.952051946, -87.754660372)
# 1 -87.623786  (41.852248185, -87.623786256)
# 2 -87.687784  (41.895732399, -87.687784384)
# 3 -87.695689   (41.81665685, -87.695688608)
# 4 -87.723990  (41.877110187, -87.723989719)
#
# [5 rows x 22 columns]

# %%
import folium
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Creating the map using folium
chicago_crime_map = folium.Map(location=[41.864073,-87.706819],
                        zoom_start=10.5,
                        tiles="CartoDB positron")

# %%
#Using groupby function to group the data by community area 
locations = df.groupby('Community Area').first()

# %%
locations2 = locations.loc[:, ['Latitude', 'Longitude', 'Location Description', 'Primary Type']]

# %%
#Checking the first 5 columns of the set list
locations2.head()
# Out:
#                  Latitude  Longitude     Location Description Primary Type
# Community Area
# 1.0             42.002590 -87.673409  RESIDENCE PORCH/HALLWAY        THEFT
# 2.0             42.007772 -87.688077                APARTMENT      BATTERY
# 3.0             41.975838 -87.659854              GAS STATION      ASSAULT
# 4.0             41.961278 -87.694157   VEHICLE NON-COMMERCIAL        THEFT
# 5.0             41.943122 -87.686292  RESIDENCE PORCH/HALLWAY        THEFT

# %%
#Needed with-in the map for descriptions when clicking on specifc areas
popup_text = """Community Index : {}<br
                Primary Type : {}<br>
                Location Description : {}<br>"""

# %%
for i in range(len(locations2)):
    lat = locations2.iloc[i][0]
    long = locations2.iloc[i][1]
    popup_text = """Community Index : {}<br>
                Primary Type : {}<br>
                Location Description : {}<br>"""
    popup_text = popup_text.format(locations2.index[i],
                               locations2.iloc[i][-1],
                               locations2.iloc[i][-2]
                               )
    folium.CircleMarker(location = [lat, long], popup= popup_text, fill = True).add_to(chicago_crime_map)

# %%
chicago_crime_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e77fedf528807aeed6ca492b3d459fda {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e77fedf528807aeed6ca492b3d459fda&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_e77fedf528807aeed6ca492b3d459fda = L.map(
#                 &quot;map_e77fedf528807aeed6ca492b3d459fda&quot;,
#                 {
#                     center: [41.864073, -87.706819],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7fcbeda2b124657a301bfa0522eb4000 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e77fedf528807aeed6ca492b3d459fda);
#
#
#             var circle_marker_9f2c8f0aea9720740c7f2a1b30bdb78f = L.circleMarker(
#                 [42.00258992, -87.67340897],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e77fedf528807aeed6ca492b3d459fda);
#
#
#         var popup_a1b52100aacbbda72c6cdf815ca40228 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_45e4a785f08bf21c482deb518932268a = $(`&lt;div id=&quot;html_45e4a785f08bf21c482deb518932268a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Community Index : 1.0&lt;br&gt;                 Primary Type : THEFT&lt;br&gt;                 Location Description : RESIDENCE PORCH/HALLWAY&lt;br&gt;&lt;/div&gt;`)[0];
#             popup_a1b52100aacbbda72c6cdf815ca40228.setContent(html_45e4a785f08bf21c482deb518932268a);
#
#
#         circle_marker_9f2c8f0aea9720740c7f2a1b30bdb78f.bindPopup(popup_a1b52100aacbbda72c6cdf815ca40228)
#         ;
#
#
#
#
#             var circle_marker_ae0382d6ae78650aa5d787d87ee4b7cb = L.circleMarker(
#                 [42.00777201, -87.6880768],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e77fedf528807aeed6ca492b3d459fda);
#
#
#         var popup_14f9f016c6dc4f6c5aad30ab9686fe60 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_bf11d8fc7f9027534cd73c001595fcda = $(`&lt;div id=&quot;html_bf11d8fc7f9027534cd73c001595fcda&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Community Index : 2.0&lt;br&gt;                 Primary Type : BATTERY&lt;br&gt;                 Location Description : APARTMENT&lt;br&gt;&lt;/div&gt;`)[0];
#             popup_14f9f016c6dc4f6c5aad30ab9686fe60.setContent(html_bf11d8fc7f9027534cd73c001595fcda);
#
#
#         circle_marker_ae0382d6ae78650aa5d787d87ee4b7cb.bindPopup(popup_14f9f016c6dc4f6c5aad30ab9686fe60)
#         ;
#
#
#
#
#             var circle_marker_5eb087020aab22f5f70efe37e7e97e88 = L.circleMarker(
#                 [41.97583764, -87.65985384],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e77fedf528807aeed6ca492b3d459fda);
#
#
#         var popup_82d92addede7b00f8d16f10bc46bc565 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_52f40af3363f91c6963c203f65f9b1b8 = $(`&lt;div id=&quot;html_52f40af3363f91c6963c203f65f9b1b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Community Index : 3.0&lt;br&gt;                 Primary Type : ASSAULT&lt;br&gt;                 Location Description : GAS STATION&lt;br&gt;&lt;/div&gt;`)[0];
#             popup_82d92addede7b00f8d16f10bc46bc565.setContent(html_52f40af3363f91c6963c203f65f9b1b8);
#
#
#         circle_marker_5eb087020aab22f5f70efe37e7e97e88.bindPopup(popup_82d92addede7b00f8d16f10bc4

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn')

# %%
df3 = pd.read_csv('Crimes_-_2001_to_Present.csv')
# Out:
# C:\Users\shemw\AppData\Local\Temp\ipykernel_25608\2550302787.py:1: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df3 = pd.read_csv('Crimes_-_2001_to_Present.csv')

# %%
print('Dataset Shape before drop_duplicate : ', df3.shape)
df3.drop_duplicates(subset=['ID', 'Case Number'], inplace=True)
print('Dataset Shape after drop_duplicate: ', df3.shape)
# Out:
# Dataset Shape before drop_duplicate :  (842340, 22)
# Dataset Shape after drop_duplicate:  (842340, 22)

# %%
df3.Date = pd.to_datetime(df3.Date, format='%m/%d/%Y %H:%M')

# %%
df3.index = pd.DatetimeIndex(df3.Date)

# %%
del list

# %%
loc_to_change = list(df3['Location Description'].value_counts()[20:].index)
desc_to_change = list(df3['Description'].value_counts()[20:].index)

# %%
df3.loc[df3['Location Description'].isin(loc_to_change) , df3.columns=='Location Description'] = 'OTHER'
df3.loc[df3['Description'].isin(desc_to_change) , df3.columns=='Description'] = 'OTHER'

# %%
plt.figure(figsize=(8,10))
df3.groupby([df3['Primary Type']]).size().sort_values(ascending=True).plot(kind='barh')
plt.title('Number of crimes by type')
plt.ylabel('Crime Type')
plt.xlabel('Number of crimes')
plt.show()

# %%
plt.figure(figsize=(7.5,10))
df3.groupby([df3['Location Description']]).size().sort_values(ascending=True).plot(kind='barh')
plt.title('Crimes by Location')
plt.ylabel('Crime Location')
plt.xlabel('Number of crimes')
plt.show()
